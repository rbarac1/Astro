# %%
from astropy.io import ascii

table = ascii.read('IC_348_Luhman.mrt', format='mrt')
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.7.2, pytest-3.8.0, py-1.6.0, pluggy-0.7.1
#
# Running tests with Astropy version 3.0.4.
# Running tests in anaconda3/lib/python3.7/site-packages/astropy.
#
# Date: 2022-10-12T09:24:18
#
# Platform: Darwin-19.6.0-x86_64-i386-64bit
#
# Executable: /Users/roccobarac/anaconda3/bin/python
#
# Full Python Version:
# 3.7.2 (default, Dec 29 2018, 00:00:04)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
#
# encodings: sys: utf-8, locale: UTF-8, filesystem: utf-8
# byteorder: little
# float info: dig: 15, mant_dig: 15
#
# Numpy: 1.15.1
# Scipy: 1.1.0
# Matplotlib: 2.2.3
# h5py: 2.8.0
# Pandas: 0.23.4
# Cython: 0.28.5
# astropy_helpers: 3.0.2
# Using Astropy options: remote_data: none.
#
# rootdir: /Users/roccobarac, inifile:
# plugins: remotedata-0.3.0, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2
# collected 10578 items / 7 skipped
#
# ...
